# %% [markdown]
# # **PROBLEMA DE NEGOCIO**

# %% [markdown]
# La necesidad de prever y optimizar el gasto de sus usuarios ha llevado a una empresa de comercio electrónico a buscar soluciones innovadoras. Como científicos de datos, hemos sido convocados para desarrollar un modelo de machine learning que pueda predecir con precisión cuánto gastará un usuario al visitar dicho sitio web.

# %% [markdown]
# ### **Tus tareas principales serán:**
#
# **1. Preprocesamiento de Datos:** Importar correctamente y analizar y comprender el conjunto de datos proporcionado, realizar limpieza de datos, eliminar atributos que no aportan valor y manejar valores faltantes.
#
# **2. Exploración y Feature Engineering:** Realizar visualizaciones para entender las relaciones entre las variables y seleccionar las características relevantes, identificar variables llaves, codificación de variables categóricas y normalización/escalado de datos.
#
# **3. Construcción de Modelos:** Experimentar con algunos algoritmos de machine learning como Linear Regression, Decision Tree Regressor, Random Forest Regressor, entre otros.
#
# **4. Evaluación y Selección del Modelo:** Evaluar los modelos utilizando métricas como el error cuadrático medio (MSE), la raíz cuadrada del error cuadrático medio (RMSE) y el coeficiente de determinación (R²). Seleccionar el modelo con el mejor rendimiento para la predicción del gasto de los usuarios.

# %% [markdown]
# # **1. Configuración del Ambiente**
#
#
# ---

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import json
from pandas import json_normalize

# %%
## Globalizando variables
global df_traffic, resultados, modelo, modelo_clasificacion

# %% [markdown]
# # **2. Preprocesamiento de Datos**
#
#
# ---

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ElProfeAlejo/Bootcamp_Databases/main/traffic_site.csv')

# %%
df_traffic = pd.read_csv('https://raw.githubusercontent.com/ElProfeAlejo/Bootcamp_Databases/main/traffic_site.csv', dtype={'date':object,'fullVisitorId':object,'visitId':object})
df_traffic.sample(5)
# Out:
#       channelGrouping      date  \
# 10987          Social  20170419
# 5361   Organic Search  20161002
# 3608           Direct  20170423
# 1460   Organic Search  20170213
# 3409   Organic Search  20170426
#
#                                                   device        fullVisitorId  \
# 10987  {"browser": "Chrome", "browserVersion": "not a...  2552279245378235025
# 5361   {"browser": "Chrome", "browserVersion": "not a...  5088388569606012967
# 3608   {"browser": "Safari", "browserVersion": "not a...  4943714929281620064
# 1460   {"browser": "Safari", "browserVersion": "not a...  4414212477567783152
# 3409   {"browser": "Firefox", "browserVersion": "not ...  3974014428079149210
#
#                                               geoNetwork  \
# 10987  {"continent": "Europe", "subContinent": "Easte...
# 5361   {"continent": "Americas", "subContinent": "Nor...
# 3608   {"continent": "Europe", "subContinent": "North...
# 1460   {"continent": "Americas", "subContinent": "Nor...
# 3409   {"continent": "Europe", "subContinent": "Weste...
#
#                             sessionId  socialEngagementType  \
# 10987  2552279245378235025_1492590290  Not Socially Engaged
# 5361   5088388569606012967_1475454271  Not Socially Engaged
# 3608   4943714929281620064_1492951663  Not Socially Engaged
# 1460   4414212477567783152_1487033026  Not Socially Engaged
# 3409   3974014428079149210_1493210598  Not Socially Engaged
#
#                                                   totals  \
# 10987  {"visits": "1", "hits": "1", "pageviews": "1",...
# 5361   {"visits": "1", "hits": "2", "pageviews": "2",...
# 3608   {"visits": "1", "hits": "1", "pageviews": "1",...
# 1460   {"visits": "1", "hits": "24", "pageviews": "23...
# 3409   {"visits": "1", "hits": "1", "pageviews": "1",...
#
#                                            trafficSource     visitId  \
# 10987  {"referralPath": "/yt/about/ro/", "campaign": ...  1492590290
# 5361   {"campaign": "(not set)", "source": "google", ...  1475454271
# 3608   {"campaign": "(not set)", "source": "(direct)"...  1492951663
# 1460   {"campaign": "(not set)", "source": "google", ...  1487033026
# 3409   {"campaign": "(not set)", "source": "google", ...  1493210598
#
#        visitNumber  visitStartTime
# 10987            1      1492590290
# 5361             1      1475454271
# 3608             1      1492951663
# 1460             1      1487033026
# 3409             1      1493210598

# %%
df_traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12283 entries, 0 to 12282
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   channelGrouping       12283 non-null  object
#  1   date                  12283 non-null  object
#  2   device                12283 non-null  object
#  3   fullVisitorId         12283 non-null  object
#  4   geoNetwork            12283 non-null  object
#  5   sessionId             12283 non-null  object
#  6   socialEngagementType  12283 non-null  object
#  7   totals                12283 non-null  object
#  8   trafficSource         12283 non-null  object
#  9   visitId               12283 non-null  object
#  10  visitNumber           12283 non-null  int64
#  11  visitStartTime        12283 non-null  int64
# dtypes: int64(2), object(10)
# memory usage: 1.1+ MB

# %%
# Crear función preprocesamiento
def preprocesamiento():
    global df_traffic, resultados, modelo, modelo_clasificacion
    df_traffic_copy = df_traffic.copy()
    
    diccionarios = ['device', 'geoNetwork', 'trafficSource', 'totals']
    
    for columna in diccionarios:
        df_traffic_copy = df_traffic_copy.join(json_normalize(df_traffic_copy[columna].apply(json.loads)))
    df_traffic_copy = df_traffic_copy.drop(columns=diccionarios)
    
    df_traffic_copy_start = df_traffic_copy.copy()
    
    for columna in df_traffic_copy.columns:
        # Verificar si la columna tiene un solo valor único
        if len(df_traffic_copy[columna].unique()) == 1:
            df_traffic_copy.drop(columns=[columna], inplace=True)
    
    df_traffic_copy.drop_duplicates(inplace=True)
    
    # Reemplazar textos por números en las columnas numéricas
    cuant = ['bounces', 'hits', 'newVisits', 'pageviews', 'transactionRevenue']
    for columna in cuant:
        df_traffic_copy[columna] = pd.to_numeric(df_traffic_copy[columna], errors='coerce')
    
    # Reemplazar nulos por cero en las columnas numéricas
    cuant = ['bounces', 'hits', 'newVisits', 'pageviews', 'transactionRevenue']
    for columna in cuant:
        df_traffic_copy[columna].fillna(0, inplace=True)
        
    # Dividir transactionRevenue por 1000000
    df_traffic_copy['transactionRevenue'] = df_traffic_copy['transactionRevenue'] / 1000000
    
    # Reemplazar números por fechas en las columnas correspondientes
    df_traffic_copy['date'] = pd.to_datetime(df_traffic_copy['date'], format='%Y%m%d')
    df_traffic_copy['visitStartTime'] = pd.to_datetime(df_traffic_copy['visitStartTime'], unit='s')
    
    return df_traffic_copy

# %%
df_traffic_copy_start = preprocesamiento().copy()

# %%
df_traffic_copy=preprocesamiento().copy()

# %%
df_traffic_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12283 entries, 0 to 12282
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   channelGrouping                 12283 non-null  object
#  1   date                            12283 non-null  datetime64[ns]
#  2   fullVisitorId                   12283 non-null  object
#  3   sessionId                       12283 non-null  object
#  4   visitId                         12283 non-null  object
#  5   visitNumber                     12283 non-null  int64
#  6   visitStartTime                  12283 non-null  datetime64[ns]
#  7   browser                         12283 non-null  object
#  8   operatingSystem                 12283 non-null  object
#  9   isMobile                        12283 non-null  bool
#  10  deviceCategory                  12283 non-null  object
#  11  continent                       12283 non-null  object
#  12  subContinent                    12283 non-null  object
#  13  country                         12283 non-null  object
#  14  region                          12283 non-null  object
#  15  metro                           12283 non-null  object
#  16  city                            12283 non-null  object
#  17  networkDomain                   12283 non-null  object
#  18  campaign                        12283 non-null  object
#  19  source                          12283 non-null  object
#  20  medium                          12283 non-null  object
#  21  keyword                         5394 non-null   object
#  22  isTrueDirect                    3885 non-null   object
#  23  referralPath                    4490 non-null   object
#  24  adwordsClickInfo.page           265 non-null    object
#  25  adwordsClickInfo.slot           265 non-null    object
#  26  adwordsClickInfo.gclId          266 non-null    object
#  27  adwordsClickInfo.adNetworkType  265 non-null    object
#  28  adwordsClickInfo.isVideoAd      265 non-null    object
#  29  adContent                       146 non-null    object
#  30  campaignCode                    1 non-null      object
#  31  hits                            12283 non-null  int64
#  32  pageviews                       12283 non-null  int64
#  33  bounces                         12283 non-null  float64
#  34  newVisits                       12283 non-null  float64
#  35  transactionRevenue              12283 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(3), object(27)
# memory usage: 3.3+ MB

# %%
df_traffic_copy_start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12283 entries, 0 to 12282
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   channelGrouping                 12283 non-null  object
#  1   date                            12283 non-null  datetime64[ns]
#  2   fullVisitorId                   12283 non-null  object
#  3   sessionId                       12283 non-null  object
#  4   visitId                         12283 non-null  object
#  5   visitNumber                     12283 non-null  int64
#  6   visitStartTime                  12283 non-null  datetime64[ns]
#  7   browser                         12283 non-null  object
#  8   operatingSystem                 12283 non-null  object
#  9   isMobile                        12283 non-null  bool
#  10  deviceCategory                  12283 non-null  object
#  11  continent                       12283 non-null  object
#  12  subContinent                    12283 non-null  object
#  13  country                         12283 non-null  object
#  14  region                          12283 non-null  object
#  15  metro                           12283 non-null  object
#  16  city                            12283 non-null  object
#  17  networkDomain                   12283 non-null  object
#  18  campaign                        12283 non-null  object
#  19  source                          12283 non-null  object
#  20  medium                          12283 non-null  object
#  21  keyword                         5394 non-null   object
#  22  isTrueDirect                    3885 non-null   object
#  23  referralPath                    4490 non-null   object
#  24  adwordsClickInfo.page           265 non-null    object
#  25  adwordsClickInfo.slot           265 non-null    object
#  26  adwordsClickInfo.gclId          266 non-null    object
#  27  adwordsClickInfo.adNetworkType  265 non-null    object
#  28  adwordsClickInfo.isVideoAd      265 non-null    object
#  29  adContent                       146 non-null    object
#  30  campaignCode                    1 non-null      object
#  31  hits                            12283 non-null  int64
#  32  pageviews                       12283 non-null  int64
#  33  bounces                         12283 non-null  float64
#  34  newVisits                       12283 non-null  float64
#  35  transactionRevenue              12283 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(3), object(27)
# memory usage: 3.3+ MB

# %%
df_traffic_copy.sample(5)
# Out:
#      channelGrouping       date        fullVisitorId  \
# 6063        Referral 2017-04-17    38653069906572885
# 6336  Organic Search 2016-12-15  9142120481991080549
# 3529  Organic Search 2017-04-29  6444049031959184377
# 9109     Paid Search 2016-08-15  4794806519550511408
# 8314          Social 2017-01-24   936890469032270161
#
#                            sessionId     visitId  visitNumber  \
# 6063    38653069906572885_1492471565  1492471565            1
# 6336  9142120481991080549_1481817590  1481817590            1
# 3529  6444049031959184377_1493481111  1493481111            1
# 9109  4794806519550511408_1471276931  1471276931            1
# 8314  0936890469032270161_1485247807  1485247807            1
#
#           visitStartTime  browser operatingSystem  isMobile deviceCategory  \
# 6063 2017-04-17 23:26:05   Safari             iOS      True         mobile
# 6336 2016-12-15 15:59:50   Safari             iOS      True         tablet
# 3529 2017-04-29 15:51:51   Chrome         Windows     False        desktop
# 9109 2016-08-15 16:02:11   Chrome             iOS      True         tablet
# 8314 2017-01-24 08:50:07  Firefox       Macintosh     False        desktop
#
#      continent      subContinent               country  \
# 6063    Europe    Western Europe                France
# 6336  Americas  Northern America         United States
# 3529    Europe    Western Europe               Germany
# 9109  Americas  Northern America         United States
# 8314      Asia      Western Asia  United Arab Emirates
#
#                              region                          metro  \
# 6063                  Ile-de-France                      (not set)
# 6336  not available in demo dataset  not available in demo dataset
# 3529                        Bavaria                      (not set)
# 9109  not available in demo dataset  not available in demo dataset
# 8314  not available in demo dataset  not available in demo dataset
#
#                                city     networkDomain  \
# 6063                          Paris   unknown.unknown
# 6336  not available in demo dataset       comcast.net
# 3529                         Munich    mnet-online.de
# 9109  not available in demo dataset    riversongs.com
# 8314  not available in demo dataset  almalcapital.com
#
#                                 campaign              source    medium  \
# 6063                           (not set)  support.google.com  referral
# 6336                           (not set)              google   organic
# 3529                           (not set)              google   organic
# 9109  AW - Dynamic Search Ads Whole Site              google       cpc
# 8314                           (not set)         youtube.com  referral
#
#                keyword isTrueDirect                            referralPath  \
# 6063               NaN          NaN  /youtube/forum/AAAAtMBnpzw3xfCBccRfq4/
# 6336    (not provided)          NaN                                     NaN
# 3529    (not provided)          NaN                                     NaN
# 9109  6qEhsCssdK0z36ri          NaN                                     NaN
# 8314               NaN          NaN                              /yt/about/
#
#      adwordsClickInfo.page adwordsClickInfo.slot      adwordsClickInfo.gclId  \
# 6063                   NaN                   NaN                         NaN
# 6336                   NaN                   NaN                         NaN
# 3529                   NaN                   NaN                         NaN
# 9109                     1                   Top  CN2BjtLlw84CFUGSfgodZg4CWQ
# 8314                   NaN                   NaN                         NaN
#
#      adwordsClickInfo.adNetworkType adwordsClickInfo.isVideoAd adContent  \
# 6063                            NaN                        NaN       NaN
# 6336                            NaN                        NaN       NaN
# 3529                            NaN                        NaN       NaN
# 9109                  Google Search                      False       NaN
# 8314                            NaN                        NaN       NaN
#
#      campaignCode  hits  pageviews  bounces  newVisits  transactionRevenue
# 6063          NaN     1          1      1.0        1.0                 0.0
# 6336          NaN    24         10      0.0        1.0                 0.0
# 3529          NaN     2          2      0.0        1.0                 0.0
# 9109          NaN     1          1      1.0        1.0                 0.0
# 8314          NaN     1          1      1.0        1.0                 0.0

# %%
for columna in df_traffic_copy.columns:
    print('========='*30)
    print(df_traffic_copy[columna].value_counts())
# Out:
# ==============================================================================================================================================================================================================================================================================
# channelGrouping
# Organic Search    5155
# Social            3052
# Direct            2011
# Referral          1438
# Paid Search        310
# Affiliates         236
# Display             77
# (Other)              4
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# date
# 2016-10-04    70
# 2016-11-17    69
# 2016-11-29    67
# 2016-11-16    67
# 2016-11-30    65
#               ..
# 2017-05-07    12
# 2016-12-24    12
# 2016-12-25    11
# 2017-04-30    10
# 2017-06-18    10
# Name: count, Length: 366, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# fullVisitorId
# 603373162136570069     24
# 7660377708313228942    24
# 5310912563447452038    20
# 3290805371994597664    20
# 4376572204985925602    19
#                        ..
# 7917907532901038094     1
# 8260329816412564664     1
# 4641112779476898481     1
# 8031235139952469596     1
# 2905034275926274980     1
# Name: count, Length: 9997, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# sessionId
# 0085919192619182437_1497163986    2
# 1336534355295742450_1500188299    2
# 3992336687808087085_1489560370    2
# 079105537511603557_1491978481     2
# 7053760850731460997_1496300394    2
#                                  ..
# 2245825143806185917_1473772714    1
# 2245825143806185917_1473804307    1
# 0330476380082401685_1473797125    1
# 6469510127903919875_1473789747    1
# 2905034275926274980_1483593737    1
# Name: count, Length: 12276, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# visitId
# 1487216938    2
# 1470680509    2
# 1497163986    2
# 1496300394    2
# 1489992920    2
#              ..
# 1473797250    1
# 1473772714    1
# 1473804307    1
# 1473797125    1
# 1483593737    1
# Name: count, Length: 12272, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# visitNumber
# 1      9445
# 2      1277
# 3       532
# 4       286
# 5       172
# 6       107
# 7        78
# 8        63
# 9        59
# 10       47
# 11       40
# 12       30
# 13       19
# 14       16
# 16       16
# 17       14
# 18       12
# 15       12
# 20        8
# 19        6
# 22        5
# 21        4
# 24        3
# 27        3
# 26        3
# 25        2
# 195       1
# 57        1
# 70        1
# 178       1
# 58        1
# 181       1
# 23        1
# 29        1
# 42        1
# 30        1
# 180       1
# 36        1
# 176       1
# 38        1
# 28        1
# 35        1
# 34        1
# 189       1
# 32        1
# 191       1
# 190       1
# 194       1
# 193       1
# 44        1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# visitStartTime
# 2017-06-01 11:19:32    2
# 2017-02-16 03:48:58    2
# 2017-07-20 08:15:13    2
# 2016-08-08 18:21:49    2
# 2016-09-02 08:23:27    1
#                       ..
# 2016-09-13 17:00:37    1
# 2016-09-13 20:24:35    1
# 2016-09-13 20:07:30    1
# 2016-09-13 13:18:34    1
# 2017-01-05 05:22:17    1
# Name: count, Length: 12279, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# browser
# Chrome                      8492
# Safari                      2441
# Firefox                      468
# Internet Explorer            278
# Edge                         149
# Android Webview              102
# Safari (in-app)               90
# Opera Mini                    75
# Opera                         73
# UC Browser                    46
# YaBrowser                     20
# Android Browser               14
# Coc Coc                       13
# Amazon Silk                    5
# Maxthon                        4
# MRCHROME                       4
# Mozilla Compatible Agent       3
# Nintendo Browser               2
# Nokia Browser                  1
# Puffin                         1
# (not set)                      1
# BlackBerry                     1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# operatingSystem
# Windows          4604
# Macintosh        3582
# Android          1706
# iOS              1480
# Linux             499
# Chrome OS         324
# (not set)          62
# Windows Phone      20
# Nintendo WiiU       2
# Firefox OS          2
# Samsung             1
# BlackBerry          1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# isMobile
# False    8978
# True     3305
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# deviceCategory
# desktop    8983
# mobile     2893
# tablet      407
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# continent
# Americas     6140
# Asia         3008
# Europe       2671
# Africa        228
# Oceania       221
# (not set)      15
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# subContinent
# Northern America      5369
# Southeast Asia        1026
# Northern Europe        843
# Southern Asia          815
# Western Europe         752
# Eastern Asia           641
# Eastern Europe         591
# South America          534
# Western Asia           511
# Southern Europe        485
# Australasia            219
# Central America        203
# Northern Africa        134
# Western Africa          34
# Caribbean               34
# Eastern Africa          32
# Southern Africa         27
# Central Asia            15
# (not set)               15
# Middle Africa            1
# Polynesia                1
# Micronesian Region       1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# country
# United States     5030
# India              705
# United Kingdom     501
# Vietnam            338
# Canada             338
#                   ...
# Greenland            1
# Suriname             1
# French Guiana        1
# Senegal              1
# Oman                 1
# Name: count, Length: 145, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# region
# not available in demo dataset    6845
# California                       1469
# New York                          395
# (not set)                         359
# England                           183
#                                  ...
# Perak                               1
# Maha Sarakham                       1
# Grand Casablanca                    1
# Western Cape                        1
# Ho Chi Minh City                    1
# Name: count, Length: 212, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# metro
# not available in demo dataset             6845
# (not set)                                 2699
# San Francisco-Oakland-San Jose CA         1309
# New York NY                                399
# London                                     174
# Los Angeles CA                             136
# Chicago IL                                 114
# Seattle-Tacoma WA                          111
# Austin TX                                   62
# Roanoke-Lynchburg VA                        50
# Washington DC (Hagerstown MD)               43
# Detroit MI                                  42
# Boston MA-Manchester NH                     40
# Atlanta GA                                  34
# Houston TX                                  32
# San Diego CA                                22
# Dallas-Ft. Worth TX                         22
# Portland OR                                 18
# Pittsburgh PA                               14
# Charlotte NC                                13
# Philadelphia PA                             13
# Denver CO                                   10
# San Antonio TX                               9
# JP_KANTO                                     8
# Columbus OH                                  6
# La Crosse-Eau Claire WI                      6
# Phoenix AZ                                   5
# North West                                   4
# Minneapolis-St. Paul MN                      4
# Kansas City MO                               3
# Central Scotland                             3
# Orlando-Daytona Beach-Melbourne FL           3
# Louisville KY                                2
# Omaha NE                                     2
# Midlands                                     2
# Grand Rapids-Kalamazoo-Battle Creek MI       2
# Las Vegas NV                                 2
# Milwaukee WI                                 2
# Cincinnati OH                                2
# Yorkshire                                    2
# Wheeling WV-Steubenville OH                  2
# Tulsa OK                                     1
# Sacramento-Stockton-Modesto CA               1
# HTV West                                     1
# Lansing MI                                   1
# Albany-Schenectady-Troy NY                   1
# Green Bay-Appleton WI                        1
# Tampa-St. Petersburg (Sarasota) FL           1
# Idaho Falls-Pocatello ID                     1
# Miami-Ft. Lauderdale FL                      1
# Butte-Bozeman MT                             1
# Chico-Redding CA                             1
# Panama City FL                               1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# city
# not available in demo dataset    6845
# Mountain View                     511
# (not set)                         450
# New York                          394
# San Francisco                     304
#                                  ...
# Courbevoie                          1
# Salvador                            1
# Iasi                                1
# Abu Dhabi                           1
# Panama City                         1
# Name: count, Length: 296, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# networkDomain
# (not set)          3435
# unknown.unknown    1995
# comcast.net         372
# rr.com              218
# verizon.net         202
#                    ...
# northwestel.net       1
# nextgentel.com        1
# cwjamaica.com         1
# d2-online.net         1
# xpressgt.co.za        1
# Name: count, Length: 1747, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# campaign
# (not set)                                          11776
# Data Share Promo                                     236
# AW - Dynamic Search Ads Whole Site                   162
# AW - Accessories                                     102
# test-liyuhz                                            4
# Retail (DO NOT EDIT owners nophakun and tianyu)        2
# AW - Apparel                                           1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# source
# google                      5393
# youtube.com                 2882
# (direct)                    2011
# mall.googleplex.com          923
# Partners                     236
#                             ...
# linkedin.com                   1
# nl.yhs4.search.yahoo.com       1
# gophergala.com                 1
# so.com                         1
# cases.corp.google.com          1
# Name: count, Length: 76, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# medium
# organic      5155
# referral     4490
# (none)       2011
# cpc           310
# affiliate     236
# cpm            77
# (not set)       4
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# keyword
# (not provided)              4942
# 6qEhsCssdK0z36ri             130
# google merchandise store      33
# Google Merchandise            30
# 1hZbAqLCbjwfgOH7              26
#                             ...
# youtube merch                  1
# Googl store backpack uk        1
# youtube e com                  1
# google printed tshirt          1
# google tshirt                  1
# Name: count, Length: 128, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# isTrueDirect
# True    3885
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# referralPath
# /                                           1042
# /yt/about/                                   931
# /yt/about/tr/                                205
# /analytics/web/                              196
# /yt/about/vi/                                195
#                                             ...
# /neo/rd                                        1
# /How-do-I-get-a-Google-I-O-t-shirt             1
# /yt/about/id/index.html                        1
# /intl/id/permissions/using-the-logo.html       1
# /intl/vi/yt/about/press/                       1
# Name: count, Length: 197, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# adwordsClickInfo.page
# 1    264
# 2      1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# adwordsClickInfo.slot
# Top    259
# RHS      6
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# adwordsClickInfo.gclId
# Cj0KEQjwuZvIBRD-8Z6B2M2Sy68BEiQAtjYS3LI8d1dPIlfea2ufVpIl8XqQYsKmi09Rdqak4YDMrU4aAiz88P8HAQ      9
# Cj0KEQjw57W9BRDM9_a-2vWJ68EBEiQAwPNFKyoNXka0H6qcqGOryxbofLW4y9plErdx22ZK43oZUE8aApJg8P8HAQ      8
# Cj0KEQiA88TFBRDYrOPKuvfY2pIBEiQA97Z8MWpY3_JRFqUJG0FMxUOHGzJI0QhtMJJeI6GAIU3emCkaArYN8P8HAQ      3
# Cj0KCQjwutXIBRDVARIsAIiVOqVHidfuvlIYOVVj_n5guptIaFb1ELNhymd7CjfVn4LQdkPHsWkMV9oaAqvUEALw_wcB    3
# Cj0KCQjwnubLBRC_ARIsAASsNNlP7S1iRYig_py0K_18BGQgimBQlZtU1M9OpyueSBRnKZmmXYFWt2YaAgBjEALw_wcB    3
#                                                                                                ..
# CjwKCAjwzMbLBRBzEiwAfFz4gep0DtF11bcp875rRGfcO5Z0ibt_0wrca4Rz66HQRFvBV7ZP1mBA3xoC8McQAvD_BwE     1
# Cj0KEQjw_qW9BRCcv-Xc5Jn-26gBEiQAM-iJhQAd-WJoV2nVph_aDEFFK2qDNV7hVbH2AmuNQiWSuRgaAovP8P8HAQ      1
# CjwKCAjw6LXIBRAUEiwA_f50PvSlIF9fpxs2NtC3Jd2q7KQN6D3-UYq6aeCH09Ia8TlcWWoNmeOUCRoC1QQQAvD_BwE     1
# CJim_IjmndQCFQiLaQodA4oJDQ                                                                      1
# CIue8vLrqdECFQoLaQodaLULpw                                                                      1
# Name: count, Length: 223, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# adwordsClickInfo.adNetworkType
# Google Search    265
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# adwordsClickInfo.isVideoAd
# False    265
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# adContent
# Google Merchandise Collection         74
# Google Online Store                   14
# Display Ad created 3/11/14            12
# Ad from 11/3/16                       10
# Ad from 12/13/16                       6
# 20% discount                           6
# {KeyWord:Google Merchandise}           6
# Display Ad created 3/11/15             4
# {KeyWord:Google Branded Gear}          4
# {KeyWord:Looking for Google Bags?}     3
# Display Ad created 11/17/14            2
# Full auto ad IMAGE ONLY                2
# Swag with Google Logos                 1
# Ad from 11/7/16                        1
# {KeyWord:Google Branded Apparel}       1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# campaignCode
# 11251kjhkvahf    1
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# hits
# 1      6124
# 2      1827
# 3       973
# 4       559
# 5       418
#        ...
# 471       1
# 67        1
# 85        1
# 130       1
# 92        1
# Name: count, Length: 96, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# pageviews
# 1      6190
# 2      1919
# 3      1012
# 4       625
# 5       471
#        ...
# 73        1
# 138       1
# 51        1
# 86        1
# 62        1
# Name: count, Length: 75, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# bounces
# 1.0    6172
# 0.0    6111
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# newVisits
# 1.0    9445
# 0.0    2838
# Name: count, dtype: int64
# ==============================================================================================================================================================================================================================================================================
# transactionRevenue
# 0.00     12119
# 13.59        3
# 33.59        3
# 19.19        3
# 27.19        2
#          ...
# 24.73        1
# 6.99         1
# 14.48        1
# 95.18        1
# 25.24        1
# Name: count, Length: 147, dtype: int64

# %%
json_data = df_traffic[['device', 'geoNetwork', 'trafficSource', 'totals']]
json_data
# Out:
#                                                   device  \
# 0      {"browser": "Chrome", "browserVersion": "not a...
# 1      {"browser": "Chrome", "browserVersion": "not a...
# 2      {"browser": "Chrome", "browserVersion": "not a...
# 3      {"browser": "Safari", "browserVersion": "not a...
# 4      {"browser": "Safari", "browserVersion": "not a...
# ...                                                  ...
# 12278  {"browser": "Chrome", "browserVersion": "not a...
# 12279  {"browser": "Chrome", "browserVersion": "not a...
# 12280  {"browser": "Chrome", "browserVersion": "not a...
# 12281  {"browser": "Chrome", "browserVersion": "not a...
# 12282  {"browser": "Android Webview", "browserVersion...
#
#                                               geoNetwork  \
# 0      {"continent": "Asia", "subContinent": "Southea...
# 1      {"continent": "Europe", "subContinent": "Easte...
# 2      {"continent": "Americas", "subContinent": "Sou...
# 3      {"continent": "Americas", "subContinent": "Nor...
# 4      {"continent": "Americas", "subContinent": "Nor...
# ...                                                  ...
# 12278  {"continent": "Europe", "subContinent": "Easte...
# 12279  {"continent": "Europe", "subContinent": "Weste...
# 12280  {"continent": "Asia", "subContinent": "Souther...
# 12281  {"continent": "Europe", "subContinent": "North...
# 12282  {"continent": "Africa", "subContinent": "South...
#
#                                            trafficSource  \
# 0      {"campaign": "(not set)", "source": "google", ...
# 1      {"campaign": "(not set)", "source": "google", ...
# 2      {"campaign": "Data Share Promo", "source": "Pa...
# 3      {"campaign": "(not set)", "source": "google", ...
# 4      {"campaign": "(not set)", "source": "google", ...
# ...                                                  ...
# 12278  {"referralPath": "/yt/about/pl/", "campaign": ...
# 12279  {"referralPath": "/yt/about/", "campaign": "(n...
# 12280  {"referralPath": "/yt/about/", "campaign": "(n...
# 12281  {"referralPath": "/yt/about/lt/", "campaign": ...
# 12282  {"referralPath": "/yt/about/", "campaign": "(n...
#
#                                                   totals
# 0      {"visits": "1", "hits": "1", "pageviews": "1",...
# 1      {"visits": "1", "hits": "1", "pageviews": "1",...
# 2      {"visits": "1", "hits": "1", "pageviews": "1",...
# 3      {"visits": "1", "hits": "1", "pageviews": "1",...
# 4      {"visits": "1", "hits": "5", "pageviews": "4",...
# ...                                                  ...
# 12278  {"visits": "1", "hits": "1", "pageviews": "1",...
# 12279  {"visits": "1", "hits": "1", "pageviews": "1",...
# 12280  {"visits": "1", "hits": "1", "pageviews": "1",...
# 12281     {"visits": "1", "hits": "2", "pageviews": "2"}
# 12282  {"visits": "1", "hits": "3", "pageviews": "3",...
#
# [12283 rows x 4 columns]

# %%
diccionarios = ['device', 'geoNetwork', 'trafficSource', 'totals']
    
for columna in diccionarios:
    json_data = json_data.join(json_normalize(json_data[columna].apply(json.loads)))
json_data = json_data.drop(columns=diccionarios)

# %%
json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12283 entries, 0 to 12282
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   browser                              12283 non-null  object
#  1   browserVersion                       12283 non-null  object
#  2   browserSize                          12283 non-null  object
#  3   operatingSystem                      12283 non-null  object
#  4   operatingSystemVersion               12283 non-null  object
#  5   isMobile                             12283 non-null  bool
#  6   mobileDeviceBranding                 12283 non-null  object
#  7   mobileDeviceModel                    12283 non-null  object
#  8   mobileInputSelector                  12283 non-null  object
#  9   mobileDeviceInfo                     12283 non-null  object
#  10  mobileDeviceMarketingName            12283 non-null  object
#  11  flashVersion                         12283 non-null  object
#  12  language                             12283 non-null  object
#  13  screenColors                         12283 non-null  object
#  14  screenResolution                     12283 non-null  object
#  15  deviceCategory                       12283 non-null  object
#  16  continent                            12283 non-null  object
#  17  subContinent                         12283 non-null  object
#  18  country                              12283 non-null  object
#  19  region                               12283 non-null  object
#  20  metro                                12283 non-null  object
#  21  city                                 12283 non-null  object
#  22  cityId                               12283 non-null  object
#  23  networkDomain                        12283 non-null  object
#  24  latitude                             12283 non-null  object
#  25  longitude                            12283 non-null  object
#  26  networkLocation                      12283 non-null  object
#  27  campaign                             12283 non-null  object
#  28  source                               12283 non-null  object
#  29  medium                               12283 non-null  object
#  30  keyword                              5394 non-null   object
#  31  adwordsClickInfo.criteriaParameters  12283 non-null  object
#  32  isTrueDirect                         3885 non-null   object
#  33  referralPath                         4490 non-null   object
#  34  adwordsClickInfo.page                265 non-null    object
#  35  adwordsClickInfo.slot                265 non-null    object
#  36  adwordsClickInfo.gclId               266 non-null    object
#  37  adwordsClickInfo.adNetworkType       265 non-null    object
#  38  adwordsClickInfo.isVideoAd           265 non-null    object
#  39  adContent                            146 non-null    object
#  40  campaignCode                         1 non-null      object
#  41  visits                               12283 non-null  object
#  42  hits                                 12283 non-null  object
#  43  pageviews                            12283 non-null  object
#  44  bounces                              6172 non-null   object
#  45  newVisits                            9445 non-null   object
#  46  transactionRevenue                   164 non-null    object
# dtypes: bool(1), object(46)
# memory usage: 4.3+ MB

# %%
columns_target = [
    "subContinent", "region", "isTrueDirect", "adwordsClickInfo.page", "adwordsClickInfo.slot", "adwordsClickInfo.gclId", "adwordsClickInfo.adNetworkType", "adwordsClickInfo.isVideoAd", "campaignCode"
]

df_traffic_copy = df_traffic_copy.drop(columns=columns_target)

# %%
df_traffic = df_traffic_copy.copy()
df_traffic.to_csv('df_traffic.csv', sep=';', index=False)

# %%
df_traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12283 entries, 0 to 12282
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   channelGrouping     12283 non-null  object
#  1   date                12283 non-null  datetime64[ns]
#  2   fullVisitorId       12283 non-null  object
#  3   sessionId           12283 non-null  object
#  4   visitId             12283 non-null  object
#  5   visitNumber         12283 non-null  int64
#  6   visitStartTime      12283 non-null  datetime64[ns]
#  7   browser             12283 non-null  object
#  8   operatingSystem     12283 non-null  object
#  9   isMobile            12283 non-null  bool
#  10  deviceCategory      12283 non-null  object
#  11  continent           12283 non-null  object
#  12  country             12283 non-null  object
#  13  metro               12283 non-null  object
#  14  city                12283 non-null  object
#  15  networkDomain       12283 non-null  object
#  16  campaign            12283 non-null  object
#  17  source              12283 non-null  object
#  18  medium              12283 non-null  object
#  19  keyword             5394 non-null   object
#  20  referralPath        4490 non-null   object
#  21  adContent           146 non-null    object
#  22  hits                12283 non-null  int64
#  23  pageviews           12283 non-null  int64
#  24  bounces             12283 non-null  float64
#  25  newVisits           12283 non-null  float64
#  26  transactionRevenue  12283 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(3), object(18)
# memory usage: 2.4+ MB

# %% [markdown]
# ### Columnas que eliminaré por no aportar nada al modelo: subContinent,region, isTrueDirect, adwordsClickInfo.page, adwordsClickInfo.slot, adwordsClickInfo.gclId, adwordsClickInfo.adNetworkType, adwordsClickInfo.isVideoAd, campaignCode, ver análisis en EDA
